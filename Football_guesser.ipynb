# %%
# Out:
# Hint: He is a Euro winner
# Guess the player's name (or type 'quit' to exit):  Dani olmo
# You guess correct
# Guess the player's name (or type 'quit' to exit):  quit
# Thanks for playing goodbye

# %%
import random
import difflib 
def play_game():
    
    # Initialize variables
    attempt = 0
    max_attempt = 3
    
    # List of players and hints
    players = [
        {
            'name': 'Lionel Messi',
            'hints': [
                'He is a one-time World Cup winner',
                'He is the legend of Barcelona',
                'He currently plays for Inter Miami in MLS'
            ]
        },
        {
            'name': 'Cristiano Ronaldo',
            'hints': [
                'He holds the record for the most goals in international football',
                'He currently plays for Al-Nassr in Saudi Arabia',
                'He is a five-time Ballon d\'Or winner'
            ]
        },
        {
            'name': 'Neymar',
            'hints': [
                'He is known for his incredible dribbling skills',
                'He currently plays for Al Hilal in Saudi Arabia',
                'He was part of the famous MSN trio at Barcelona'
            ]
        },
        {
            'name': 'Kylian Mbappé',
            'hints': [
                'He scored a hat-trick in the 2022 World Cup final',
                'He currently plays for Real Madrid',
                'He broke through at Monaco at the age of 16'
            ]
        },
        {
            'name': 'Vinícius Junior',
            'hints': [
                'He is known for his explosive pace and dribbling',
                'He currently plays for Real Madrid',
                'He is one of Brazil\'s top attacking talents'
            ]
        },
        {
            'name': 'Erling Haaland',
            'hints': [
                'He is a goal-scoring machine known for his physical dominance',
                'He currently plays for Manchester City',
                'He broke records in the Premier League for most goals in a season'
            ]
        },
        {
            'name': 'Harry Kane',
            'hints': [
                'He is England\'s all-time top scorer',
                'He currently plays for Bayern Munich',
                'Known for his playmaking and finishing ability'
            ]
        },
        {
            'name': 'Robert Lewandowski',
            'hints': [
                'He has won multiple European Golden Shoes',
                'He currently plays for Barcelona',
                'Known for his incredible positioning and finishing'
            ]
        },
        {
            'name': 'Jude Bellingham',
            'hints': [
                'He is one of England\'s brightest young talents',
                'He currently plays for Real Madrid as a midfielder',
                'Made his debut at age 16 with Birmingham City'
            ]
        },
        {
            'name': 'Son Heung-min',
            'hints': [
                "Known as South Korea's greatest footballer ever",
                "Plays as a winger for Tottenham Hotspur",
                "Famous for his speed and long-range goals"
            ]
        },
        {
            "name": "Mohamed Salah",
            "hints": [
                "The best player in the world in 2025",
                "Plays as a winger for Liverpool",
                "Known for consistency, goal-scoring, and leadership"
            ]
        },
        {
            "name": "Khvicha Kvaratskhelia",
            "hints": [
                "A Georgian winger known for electrifying dribbles",
                "Currently plays for PSG after leaving Napoli",
                "Famous for creativity and goal-scoring ability"
            ]
        },
        {
            "name": "Alexander Isak",
            "hints": [
                "A Swedish striker playing for Newcastle United",
                "Known for pace, technical skill, and finishing ability",
                "One of the Premier League's deadliest forwards"
            ]
        },
        {
            "name": "Antoine Griezmann",
            "hints": [
                "A versatile forward playing for Atlético Madrid",
                "Known for creativity and clutch performances",
                "Won multiple titles with France and club teams"
            ]
        },
        {
            "name": "Marcus Rashford",
            "hints": [
                "Plays as a forward for Manchester United",
                "Known for charity work alongside football achievements",
                "Famous for pace and versatility"
            ]
        },
        {
            "name": "Luis Suárez",
            "hints": [
                "A legendary striker from Uruguay who played with Messi at Barcelona",
                "Currently plays for Inter Miami in MLS",
                "Known for his aggressive style and clinical finishing"
            ]
        },
        {
            "name": "Karim Benzema",
            "hints": [
                "Ballon d'Or winner in 2022",
                "Currently plays for Al-Ittihad in Saudi Arabia",
                "One of Real Madrid's greatest strikers ever"
            ]
        },
         {
            "name": "Federico Valverde",
            "hints": [
                "A Uruguayan midfielder known for his incredible work rate",
                "Currently plays for Real Madrid",
                "Famous for scoring stunning long-range goals"
            ]
        },
        {
            "name": "Florian Wirtz",
            "hints": [
                "A German playmaker known for his dribbling and passing",
                "Currently plays for Bayer Leverkusen",
                "Emerging as one of the most exciting young talents"
            ]
        },
        {
            "name": "Joshua Kimmich",
            "hints": [
                "A complete midfielder playing for Bayern Munich",
                "Known for intelligence, passing, and defensive ability",
                "One of the best all-around players in the game"
            ]
        },
         {
            "name": "Bukayo Saka",
            "hints": [
                "A dynamic attacking force playing for Arsenal",
                "Known for consistency and ability to perform in big games",
                "One of the most popular players in football"
            ]
        },
        {
            "name": "Virgil van Dijk",
            "hints": [
                "A dominant defender playing for Liverpool",
                "Known for leadership and defensive prowess",
                "One of the best defenders in the world"
            ]
        },
         {
            "name": "Raphinha",
            "hints": [
                "A Brazilian winger playing for Barcelona",
                "Known for skill and creativity on the wing",
                "Emerging as a top talent in La Liga"
            ]
        },
         {
            "name": "Jamal Musiala",
            "hints": [
                "A German midfielder playing for Bayern Munich",
                "Known for versatility and attacking flair",
                "One of the brightest young talents in football"
            ]
        },
        {
            "name": "Martin Odegaard",
            "hints": [
                "A Norwegian midfielder playing for Arsenal",
                "Known for creativity and playmaking ability",
                "Key figure in Arsenal's midfield"
            ]
        },
    
        {
          	"name":"Cole Palmer", 
    		"hints":[
    		"Known as Chelsea's player of the year 2024."
    		"Cold celebration trademarked!"
    	]
    }
    ]
    
    # Randomly select a player
    selected_player = random.choice(players)

    while attempt < max_attempt:
        # Display a random hint and remove it from the list
        if selected_player['hints']:
            selected_hint = random.choice(selected_player['hints'])
            print(f"Hint: {selected_hint}")
            selected_player['hints'].remove(selected_hint)
        else:
            print("No more hints available!")

        # Get user's guess
        user_guess = input("Guess the player's name (or type 'quit' to exit): ").strip().lower()

        if user_guess == 'quit':  # Allow user to quit the game
            print('Thanks for playing! Goodbye!')
            return False

        # Check if guess matches closely using difflib
        close_matches = difflib.get_close_matches(user_guess, [selected_player['name'].lower()], n=1, cutoff=0.8)

        if close_matches:  # If there is a close match
            print('You guessed correctly! 🎉')
            return True
        else:  # Handle incorrect guess
            attempt += 1
            print(f"Wrong guess, try again. You have {max_attempt - attempt} attempts left.")

        if attempt >= max_attempt:  # Check if max attempts are reached
            print(f"You've used all your attempts! The correct answer was: {selected_player['name']}")
            return False

# Main loop to allow replaying
while True:
    play_game()  # Call the play_game() function here
    play_again = input("Do you want to play again? (yes/no): ").strip().lower()
    if play_again != "yes":
        print("Thanks for playing! See you next time!")
        break
# Out:
# Hint: He has won multiple European Golden Shoes
# Guess the player's name (or type 'quit' to exit):  quit
# Thanks for playing! Goodbye!
# Do you want to play again? (yes/no):  no
# Thanks for playing! See you next time!
